# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools

# %%
plot_data = np.load('plot_3d_event.npy')
grid = plot_data[0]
hits = np.concatenate(np.concatenate(plot_data[1]))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
dot_size = np.pi*(0.5*hits)**2
ax.scatter(grid[:,0:1], 
           grid[:,1:2],
           grid[:,2:3],
           s=dot_size)
#plt.savefig('3d_event_view.pdf')
plt.show()
