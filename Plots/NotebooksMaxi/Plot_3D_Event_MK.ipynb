# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools
import os
import tables
import h5py

# %%
base_path = '/scratch9/mkron/data/training_data/second_dataset'
data_file = os.path.join(base_path, 'File_0.h5')
file = h5py.File(data_file, "r")

# %%
charge = file["charge"]
reco_vals = file["reco_vals"]
#time = file["time"]

# %%
i = 15
xlen = np.shape(charge[i])[0]
ylen = np.shape(charge[i])[1]
zlen = np.shape(charge[i])[2]
x,y,z = np.meshgrid(range(xlen), range(ylen), range(zlen))
hits = np.concatenate(np.concatenate(charge[i]))

# %%
for i in xrange(3000):
    if reco_vals[i]["ClassificationLabel"] == 3:
        if reco_vals[i]["CoincidenceLabel"] == 1: 
            print i
# Out:
# 1
# 22
# 128
# 138
# 139

# %%
i = 1
xlen = np.shape(charge[i])[0]
ylen = np.shape(charge[i])[1]
zlen = np.shape(charge[i])[2]
x,y,z = np.meshgrid(range(xlen), range(ylen), range(zlen))
hits = np.concatenate(np.concatenate(charge[i]))

log = True
#log = False

for j, keys in enumerate(reco_vals[i]):
    print "{}: {}".format(reco_vals[i].dtype.names[j], keys) 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
if log:
    dot_size = np.log10(np.pi*(0.5*hits)**2)
else:
    dot_size = np.pi*(0.5*hits)**2
ax.scatter(x, 
           y,
           z,
           s=dot_size)
#plt.savefig('3d_event_view.pdf')
plt.show()
# Out:
# depositedE: 63467094.242
# firstParticle: 2212.0
# energyFirstParticle: 9168.05859375
# ClassificationLabel: 3.0
# StartingLabel: 1.0
# UpDownLabel: 0.0
# CoincidenceLabel: 1.0
# /home/ga38tul/.local/lib/python2.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log10
